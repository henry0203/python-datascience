# %%
import numpy as np
import pandas as pd
mean = np.mean([1,2])
array1 = np.genfromtxt("Houses.csv", delimiter=",", dtype=int)
google_app = pd.read_table("GooglePlayStore.csv", sep=",")
black_friday = pd.read_csv("BlackFriday.csv")
print(array1)
print(google_app)
print(black_friday)
google_app
black_friday.info()
black_friday.columns
black_friday.head(10)
# Out:
# 1.5
# [[212000   4148  25264]
#  [230000   2501  11891]
#  [339000   4374  25351]
#  [289000   2398  22215]
#  [160000   2536   9234]
#  [ 85000   2368  13329]
#  [ 85000   1264   8407]
#  [145000   1572  12588]
#  [164000   2375  16204]
#  [123500   1161   9626]
#  [180000   1542   8755]
#  [159500   1464  14636]
#  [156000   2240  21780]
#  [146500   1269  11250]
#  [101500    924   7361]
#  [109800    768  10497]
#  [182000   1320  15768]
#  [110000   1845  12153]
#  [125000   1274  13634]
#  [ 80000   1905  10890]]
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas

# %%
plt.plot()
plt.draw()

# %%
group_age=black_friday.groupby("Age")
group_age

# %%
group_age.count()
# Out:
#        User_ID  Product_ID  Gender  Occupation  City_Category  \
# Age
# 0-17     14707       14707   14707       14707          14707
# 18-25    97634       97634   97634       97634          97634
# 26-35   214690      214690  214690      214690         214690
# 36-45   107499      107499  107499      107499         107499
# 46-50    44526       44526   44526       44526          44526
# 51-55    37618       37618   37618       37618          37618
# 55+      20903       20903   20903       20903          20903
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Age
# 0-17                        14707           14707               14707
# 18-25                       97634           97634               97634
# 26-35                      214690          214690              214690
# 36-45                      107499          107499              107499
# 46-50                       44526           44526               44526
# ...

# %%
customer_buy=dict()
for age, group in group_age:
    customer_buy[age]=sum(group["Purchase"])
    #print(age) #category name
    #print(group) #subdataframe

# %%
customer_buy
# Out:
# {'0-17': 132659006,
#  '18-25': 901669280,
#  '26-35': 1999749106,
#  '36-45': 1010649565,
#  '46-50': 413418223,
#  '51-55': 361908356,
#  '55+': 197614842}

# %%
plt.plot(list(customer_buy.keys()), list(customer_buy.values()))
plt.draw()
#list(customer_buy.keys())

# %%
plt.plot(list(customer_buy.keys()), list(customer_buy.values()), marker='x')
plt.draw()

# %%
plt.plot(list(customer_buy.keys()), list(customer_buy.values()), marker='o',linestyle="")
plt.xlabel("age categories")
plt.ylabel("Sales sum")
plt.title("Total sales/ age categories", y=1.05)
plt.draw()

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.scatter(list(customer_buy.keys()), list(customer_buy.values()), c=list(customer_buy.values()), cmap="seismic", marker='D', s=100) # matplolib color
plt.xlabel("age categories")
plt.ylabel("Sales sum")
plt.title("Total sales/ age categories", y=1.05)
plt.colorbar()  #vertical by default, set in param orientation="horizontal" if horizontal
plt.draw()
plt.savefig("mon_graphique.png", bbox_inches="tight")

# %%
data=black_friday["Gender"].value_counts()

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.bar(data.index, data, color=["blue", "red"])
plt.xlabel("buyer gender")
plt.ylabel("buying number")
plt.title("Number of buying for men/ women")
plt.draw()

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.boxplot(black_friday["Purchase"])
plt.xticks([1],["Ventes"])
plt.draw()

# %%
data=black_friday["Age"].value_counts()

# %%
data
# Out:
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: Age, dtype: int64

# %%
plt.rcParams["figure.figsize"]=[9,9]
plt.pie(data.values, labels=data.index, autopct="%1.1f%%", shadow=True, startangle=90)
plt.draw()

# %%
plt.rcParams["figure.figsize"]=[9,9]
plt.subplot(221) #nber of rows, cols, place 1rst element
plt.bar(data.index, data, color=["blue", "red"])
plt.xlabel("buyer gender")
plt.ylabel("buying number")
plt.xticks(rotation="vertical")
plt.title("Number of buying for men/ women")
plt.subplot(222)
plt.boxplot(black_friday["Purchase"])
plt.xticks([1],["Ventes"])
plt.tight_layout()
plt.subplot(212)
plt.scatter(list(customer_buy.keys()), list(customer_buy.values()), c=list(customer_buy.values()), cmap="seismic", marker='D', s=100) # matplolib color
plt.xlabel("age categories")
plt.ylabel("Sales sum")
plt.title("Total sales/ age categories", y=1.05)
plt.colorbar()
plt.tight_layout()
plt.draw()

# %%
import seaborn as sns
sns.boxplot(x="Gender", y="Purchase", hue="Age", data=black_friday,palette="Set1")
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.draw()

# %%
sns.countplot(x="Age", hue="Gender", data=black_friday,palette="Set1")
plt.draw()

# %%
subset=black_friday.sample(3000)
sns.catplot(x="Age",y="Purchase",hue="Gender",data=subset,kind="swarm")
plt.draw()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 1. Tracer un barplot avec la fonction sns.barplot représentant l'addition totale payée et en séparant ces données par sexe
sns.barplot(x="sex", y="total_bill", data=tips)
plt.draw()

# %%
# 2. Etudier la distribution de la variable total_bill grâce à la fonction distplot
sns.distplot(tips["total_bill"], kde=False) #input serie => one column
plt.draw()

# %%
# 3.Utiliser la fonction jointplot de seaborn pour tracer la variable total_bill (X) en fonction de la variable tip (Y)
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")
plt.draw()

# %%
# 4. Utiliser la fonction pairplot de Seaborn pour étudier les relations entre nos variables
sns.pairplot(tips)
plt.draw()

# %%
# 5. Tracer le boxplot de la variable total_bill en créant un boxplot par jour (day) 
# et en utilisant la variable sex dans l'option hue
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
plt.draw()
