# %%
import pandas

# %%
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google_app.to_csv("mon_dataframe.csv")

# %%
google_app.set_index("App")
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google_app_index = google_app.set_index("App")

# %%
google_app_index
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_app_index.iloc[4, 3]
# Out:
# '2.8M'

# %%
google_app_index.loc["Pixel Draw - Number Art Coloring Book", "Size"]
# Out:
# '2.8M'

# %%
google_app_index.loc["Udemy - Online Courses", :]
# Out:
#                          Category  Rating Reviews Size    Installs  Type  \
# App
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
#
#                        Price Content Rating     Genres    Last Updated  \
# App
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
#
#                        Current Ver Android Ver
# App
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up

# %%
google_app_index.iloc[0:4, :]
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
#
#                                                     Type Price Content Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      Free     0       Everyone
# ...

# %%
google_app_index.iloc[:, 0:4].head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M
# Coloring book moana                                    967   14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M
# Sketch - Draw & Paint                               215644   25M
# Pixel Draw - Number Art Coloring Book                  967  2.8M

# %%
google_app_index.loc[:, ["Category", "Rating", "Reviews", "Size"]]
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_app_index.iloc[2:5, 3:8]
# Out:
#                                                     Size     Installs  Type  \
# App
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  8.7M   5,000,000+  Free
# Sketch - Draw & Paint                                25M  50,000,000+  Free
# Pixel Draw - Number Art Coloring Book               2.8M     100,000+  Free
#
#                                                    Price Content Rating
# App
# U Launcher Lite – FREE Live Cool Themes, Hide Apps     0       Everyone
# Sketch - Draw & Paint                                  0           Teen
# Pixel Draw - Number Art Coloring Book                  0       Everyone

# %%
category = google_app_index["Category"]

# %%
category.head()
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook        ART_AND_DESIGN
# Coloring book moana                                   ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    ART_AND_DESIGN
# Sketch - Draw & Paint                                 ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                 ART_AND_DESIGN
# Name: Category, dtype: object

# %%
google_app_index["Category_bis"]=category

# %%
google_app_index.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %%
google_app_index.drop(["Category_bis","Android Ver"], axis=1)
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_app.shape
# Out:
# (10841, 13)

# %%
google_app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
google_app.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
google_app_no_nan = google_app.dropna()

# %%
google_app_no_nan.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
google_app_no_nan.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_app_no_nan.sort_values(by="Rating").head()
# Out:
#                                    App      Category  Rating Reviews  Size  \
# 625            House party - live chat        DATING     1.0       1  9.2M
# 6319  BJ Bridge Standard American 2018          GAME     1.0       1  4.9M
# 7926              Tech CU Card Manager       FINANCE     1.0       2  7.2M
# 7383                    Thistletown CI  PRODUCTIVITY     1.0       1  6.6M
# 5978     Truck Driving Test Class 3 BC        FAMILY     1.0       1  2.0M
#
#      Installs  Type  Price Content Rating        Genres    Last Updated  \
# 625       10+  Free      0     Mature 17+        Dating   July 31, 2018
# 6319   1,000+  Free      0       Everyone          Card    May 21, 2018
# 7926   1,000+  Free      0       Everyone       Finance   July 25, 2017
# 7383     100+  Free      0       Everyone  Productivity  March 15, 2018
# 5978      50+  Paid  $1.49       Everyone     Education   April 9, 2012
#
#      Current Ver   Android Ver
# 625         3.52  4.0.3 and up
# ...

# %%
google_app_no_nan.describe()
# Out:
#             Rating
# count  9360.000000
# mean      4.191838
# std       0.515263
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %%
google_app_no_nan.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_no_nan.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count     9360     9360  9360.000000    9360                9360        9360
# unique    8190       33          NaN    5990                 413          19
# top     ROBLOX   FAMILY          NaN       2  Varies with device  1,000,000+
# freq         9     1746          NaN      83                1637        1576
# mean       NaN      NaN     4.191838     NaN                 NaN         NaN
# std        NaN      NaN     0.515263     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN     5.000000     NaN                 NaN         NaN
#
# ...

# %%
google_app_no_nan["Installs"]=google_app_no_nan["Installs"].apply(lambda x: x.replace(",", ""))
google_app_no_nan["Installs"]=google_app_no_nan["Installs"].apply(lambda x: x.replace("+", ""))
# Out:
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
google_app_no_nan.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_no_nan["Installs"]=google_app_no_nan["Installs"].apply(lambda x: int(x))
# Out:
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
google_app_no_nan.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_no_nan.describe()
# Out:
#             Rating      Installs
# count  9360.000000  9.360000e+03
# mean      4.191838  1.790875e+07
# std       0.515263  9.126637e+07
# min       1.000000  1.000000e+00
# 25%       4.000000  1.000000e+04
# 50%       4.300000  5.000000e+05
# 75%       4.500000  5.000000e+06
# max       5.000000  1.000000e+09

# %%
google_app_no_nan["Reviews"]=google_app_no_nan["Reviews"].apply(lambda x: int(x))
# Out:
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
google_app_no_nan.describe()
# Out:
#             Rating       Reviews      Installs
# count  9360.000000  9.360000e+03  9.360000e+03
# mean      4.191838  5.143767e+05  1.790875e+07
# std       0.515263  3.145023e+06  9.126637e+07
# min       1.000000  1.000000e+00  1.000000e+00
# 25%       4.000000  1.867500e+02  1.000000e+04
# 50%       4.300000  5.955000e+03  5.000000e+05
# 75%       4.500000  8.162750e+04  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+09

# %%
google_app_no_nan["Type"].value_counts()
# Out:
# Free    8715
# Paid     645
# Name: Type, dtype: int64

# %%
google_app_no_nan.loc[google_app_no_nan["Rating"]>4.5, :]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
google_app_no_nan.loc[google_app_no_nan["Category"]=="BUSINESS", :]
# Out:
#                                                      App  Category  Rating  \
# 187                         Visual Voicemail by MetroPCS  BUSINESS     4.1
# 188                                    Indeed Job Search  BUSINESS     4.3
# 189                                          Uber Driver  BUSINESS     4.4
# 190                                 ADP Mobile Solutions  BUSINESS     4.3
# 191                               Snag - Jobs Hiring Now  BUSINESS     4.3
# ...                                                  ...       ...     ...
# 10624                              Employ Florida Mobile  BUSINESS     2.9
# 10659                                                 FN  BUSINESS     5.0
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...  BUSINESS     4.6
# 10754                                     SCM FPS Status  BUSINESS     4.2
# 10810                                  Fr Lupupa Sermons  BUSINESS     4.8
#
# ...

# %%
google_app_no_nan["Category"]=="BUSINESS"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10834    False
# 10836    False
# 10837    False
# 10839    False
# 10840    False
# Name: Category, Length: 9360, dtype: bool

# %%
google_app_no_nan.loc[(google_app_no_nan["Category"]=="BUSINESS") & (google_app_no_nan["Rating"]>4.5), :]
# Out:
#                                                      App  Category  Rating  \
# 196                           Job Search by ZipRecruiter  BUSINESS     4.8
# 206                                         Call Blocker  BUSINESS     4.6
# 208                           Square Point of Sale - POS  BUSINESS     4.6
# 221                                        Myanmar 2D/3D  BUSINESS     4.6
# 224                       ATI Cargoes and Transportation  BUSINESS     4.7
# ...                                                  ...       ...     ...
# 10412                                             FH App  BUSINESS     4.9
# 10529                                 FK CLASSIC FOR YOU  BUSINESS     5.0
# 10659                                                 FN  BUSINESS     5.0
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...  BUSINESS     4.6
# 10810                                  Fr Lupupa Sermons  BUSINESS     4.8
#
# ...

# %%
google_app_no_nan.loc[(google_app_no_nan["Category"]=="BUSINESS") & (google_app_no_nan["Rating"]>4.5) & (google_app_no_nan["Type"]=="Free"), :]
# Out:
#                                                      App  Category  Rating  \
# 196                           Job Search by ZipRecruiter  BUSINESS     4.8
# 206                                         Call Blocker  BUSINESS     4.6
# 208                           Square Point of Sale - POS  BUSINESS     4.6
# 221                                        Myanmar 2D/3D  BUSINESS     4.6
# 224                       ATI Cargoes and Transportation  BUSINESS     4.7
# ...                                                  ...       ...     ...
# 10412                                             FH App  BUSINESS     4.9
# 10529                                 FK CLASSIC FOR YOU  BUSINESS     5.0
# 10659                                                 FN  BUSINESS     5.0
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...  BUSINESS     4.6
# 10810                                  Fr Lupupa Sermons  BUSINESS     4.8
#
# ...

# %%
google_app_no_nan["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
google_app_no_nan["Price"] = google_app_no_nan["Price"].apply(lambda x: x.replace("$", ""))
google_app_no_nan["Price"] = google_app_no_nan["Price"].apply(lambda x: float(x))
# Out:
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
google_app_no_nan["Price"].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
type(google_app_no_nan["Price"])
# Out:
# pandas.core.series.Series

# %%
google_app_no_nan.groupby("Category").describe()
# Out:
#                      Rating                                                   \
#                       count      mean       std  min    25%  50%    75%  max
# Category
# ART_AND_DESIGN         61.0  4.377049  0.328326  3.4  4.100  4.4  4.700  5.0
# AUTO_AND_VEHICLES      73.0  4.190411  0.543692  2.1  4.000  4.3  4.600  4.9
# BEAUTY                 42.0  4.278571  0.362603  3.1  4.000  4.3  4.575  4.9
# BOOKS_AND_REFERENCE   178.0  4.346067  0.429046  2.7  4.100  4.5  4.600  5.0
# BUSINESS              303.0  4.121452  0.624422  1.0  3.900  4.3  4.500  5.0
# COMICS                 58.0  4.155172  0.537758  2.8  3.825  4.4  4.500  5.0
# COMMUNICATION         328.0  4.158537  0.426192  1.0  4.000  4.3  4.400  5.0
# DATING                195.0  3.970769  0.630510  1.0  3.700  4.1  4.400  5.0
# EDUCATION             155.0  4.389032  0.251894  3.5  4.200  4.4  4.600  4.9
# ENTERTAINMENT         149.0  4.126174  0.302556  3.0  3.900  4.2  4.300  4.7
# ...

# %%
google_app_no_nan.groupby(["Category", "Genres"]).describe()
# Out:
#                                                         Rating            \
#                                                          count      mean
# Category          Genres
# ART_AND_DESIGN    Art & Design                            55.0  4.380000
#                   Art & Design;Creativity                  5.0  4.440000
#                   Art & Design;Pretend Play                1.0  3.900000
# AUTO_AND_VEHICLES Auto & Vehicles                         73.0  4.190411
# BEAUTY            Beauty                                  42.0  4.278571
# ...                                                        ...       ...
# TRAVEL_AND_LOCAL  Travel & Local;Action & Adventure        1.0  4.100000
# VIDEO_PLAYERS     Video Players & Editors                158.0  4.063924
#                   Video Players & Editors;Creativity       1.0  4.100000
#                   Video Players & Editors;Music & Video    1.0  4.000000
# ...

# %%
# 1. Quels sont les noms, categories, genres des apps les plus installées
max_install = google_app_no_nan["Installs"].max()
max_install
# Out:
# 1000000000

# %%
google_app_no_nan.loc[google_app_no_nan["Installs"]==max_install, ["App", "Category", "Genres", "Installs"]]
# Out:
#                                            App             Category  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION
# 336                         WhatsApp Messenger        COMMUNICATION
# 338               Google Chrome: Fast & Secure        COMMUNICATION
# 340                                      Gmail        COMMUNICATION
# 341                                   Hangouts        COMMUNICATION
# 381                         WhatsApp Messenger        COMMUNICATION
# 382   Messenger – Text and Video Chat for Free        COMMUNICATION
# 386                                   Hangouts        COMMUNICATION
# 391              Skype - free IM & video calls        COMMUNICATION
# 411               Google Chrome: Fast & Secure        COMMUNICATION
# 451                                      Gmail        COMMUNICATION
# 464                                   Hangouts        COMMUNICATION
# ...

# %%
#2. Quel est le plus grand nombre de reviews ? Quel est le nom et la note globale de l'application concernée ?
max_reviews = google_app_no_nan["Reviews"].max()
max_reviews
# Out:
# 78158306

# %%
#google_app_no_nan["Reviews"]=google_app_no_nan["Reviews"].apply(lambda x: int(x))
google_app_no_nan.loc[google_app_no_nan["Reviews"]==max_reviews, ["App", "Rating"]]
# Out:
#            App  Rating
# 2544  Facebook     4.1

# %%
#3. Afficher colonnes 2, 5, 6 et les lignes 3:16
google_app_no_nan.iloc[2:16,[1,4,5]]
# Out:
#           Category  Size  Installs
# 2   ART_AND_DESIGN  8.7M   5000000
# 3   ART_AND_DESIGN   25M  50000000
# 4   ART_AND_DESIGN  2.8M    100000
# 5   ART_AND_DESIGN  5.6M     50000
# 6   ART_AND_DESIGN   19M     50000
# 7   ART_AND_DESIGN   29M   1000000
# 8   ART_AND_DESIGN   33M   1000000
# 9   ART_AND_DESIGN  3.1M     10000
# 10  ART_AND_DESIGN   28M   1000000
# 11  ART_AND_DESIGN   12M   1000000
# 12  ART_AND_DESIGN   20M  10000000
# 13  ART_AND_DESIGN   21M    100000
# 14  ART_AND_DESIGN   37M    100000
# 16  ART_AND_DESIGN  5.5M    500000

# %%
#4. Combien y-a-t-il d'application sans restrinction d'âge
google_app_no_nan.loc[google_app_no_nan["Content Rating"]=="Everyone"].shape
# Out:
# (7414, 13)

# %%
#5. Dans quelle catégorie y a-t-il le plus d'application 
google_app_category_count = google_app_no_nan.groupby(["Category"]).agg(["count"])["App"]
google_app_category_count.loc[google_app_category_count["count"]==1746]
# Out:
#           count
# Category
# FAMILY     1746

# %%
#6. Quelle est l'application vendue la plus chère
max_price = google_app_no_nan["Price"].max()
google_app_no_nan[google_app_no_nan["Price"]==max_price]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M     10000
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle  May 3, 2018       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %%
# Out:
#                                  App   Category  Rating  Reviews  Size  \
# 4197          most expensive app (H)     FAMILY     4.3        6  1.5M
# 4362                      💎 I'm rich  LIFESTYLE     3.8      718   26M
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M
# 5351                       I am rich  LIFESTYLE     3.8     3547  1.8M
# 5354                  I am Rich Plus     FAMILY     4.0      856  8.7M
# 5356               I Am Rich Premium    FINANCE     4.1     1867  4.7M
# 5357             I am extremely Rich  LIFESTYLE     2.9       41  2.9M
# 5358                      I am Rich!    FINANCE     3.8       93   22M
# 5359              I am rich(premium)    FINANCE     3.5      472  965k
# 5362                   I Am Rich Pro     FAMILY     4.4      201  2.7M
# 5364  I am rich (Most expensive app)    FINANCE     4.1      129  2.7M
# 5366                       I Am Rich     FAMILY     3.6      217  4.9M
# ...

# %%
google_app_no_nan[google_app_no_nan["Type"]=="Free"].count()
# Out:
# App               8715
# Category          8715
# Rating            8715
# Reviews           8715
# Size              8715
# Installs          8715
# Type              8715
# Price             8715
# Content Rating    8715
# Genres            8715
# Last Updated      8715
# Current Ver       8715
# Android Ver       8715
# dtype: int64

# %%
google_app_no_nan[google_app_no_nan["Type"]!="Free"].count()
# Out:
# App               645
# Category          645
# Rating            645
# Reviews           645
# Size              645
# Installs          645
# Type              645
# Price             645
# Content Rating    645
# Genres            645
# Last Updated      645
# Current Ver       645
# Android Ver       645
# dtype: int64

# %%
google_app_no_nan["Installs"].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,        100,        500,
#                10,          5,         50,          1])

# %%
google_app_no_nan[google_app_no_nan["Installs"]==1000000000]["App"].unique()
# Out:
# array(['Google Play Books', 'Messenger – Text and Video Chat for Free',
#        'WhatsApp Messenger', 'Google Chrome: Fast & Secure', 'Gmail',
#        'Hangouts', 'Skype - free IM & video calls', 'Google Play Games',
#        'Subway Surfers', 'Facebook', 'Instagram', 'Google+',
#        'Google Photos', 'Maps - Navigate & Explore', 'Google Street View',
#        'Google', 'Google Drive', 'YouTube', 'Google Play Movies & TV',
#        'Google News'], dtype=object)
